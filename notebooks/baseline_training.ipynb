# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/dataset/dataset.zip'
destination_path = '/content/dataset'

# !unzip {file_path} -d {destination_path}
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/dataset/train/images/36_Football_americanfootball_ball_36_842.jpg
#   inflating: /content/dataset/dataset/train/images/26_Soldier_Drilling_Soldiers_Drilling_26_910.jpg
#   inflating: /content/dataset/dataset/train/images/51_Dresses_wearingdress_51_720.jpg
#   inflating: /content/dataset/dataset/train/images/50_Celebration_Or_Party_houseparty_50_1018.jpg
#   inflating: /content/dataset/dataset/train/images/23_Shoppers_Shoppers_23_284.jpg
#   inflating: /content/dataset/dataset/train/images/26_Soldier_Drilling_Soldiers_Drilling_26_822.jpg
#   inflating: /content/dataset/dataset/train/images/51_Dresses_wearingdress_51_267.jpg
#   inflating: /content/dataset/dataset/train/images/2_Demonstration_Demonstrators_2_125.jpg
#   inflating: /content/dataset/dataset/train/images/9_Press_Conference_Press_Conference_9_472.jpg
#   inflating: /content/dataset/dataset/train/images/0_Parade_Parade_0_730.jpg
# ...

# %%
! pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.8/112.6 GB disk)

# %%
! yolo train \
  model=yolov8n.pt \
  data=/content/dataset/dataset/data.yaml \
  epochs=5 \
  imgsz=640 \
  name=yolo_custom_run
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Define the source and destination paths
SOURCE_DIR="/content/runs/detect/yolo_custom_run3"
DEST_DIR="/content/drive/MyDrive/yolo_project_results/"

# Copy the entire results folder to your Drive
! cp -r {SOURCE_DIR} {DEST_DIR}
